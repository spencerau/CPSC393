# %% [markdown]
# # Variational AutoEncoder
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/05/03<br>
# **Last modified:** 2020/05/03<br>
# **Description:** Convolutional Variational AutoEncoder (VAE) trained on MNIST digits.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from plotnine import *

from tensorflow.keras.callbacks import CSVLogger

# %% [markdown]
# ## Create a sampling layer

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Build the encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 2)                    34        ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Build the decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Define the VAE as a `Model` with a custom `train_step`

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# ## Train the VAE

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

csv_logger = CSVLogger('training.csv', append=False)

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits,
        epochs=30,
        batch_size=128,
        callbacks = [csv_logger])
# Out:
# Epoch 1/30
# 547/547 [==============================] - 8s 10ms/step - loss: 149.2165 - reconstruction_loss: 142.8098 - kl_loss: 6.4186
# Epoch 2/30
# 547/547 [==============================] - 5s 9ms/step - loss: 149.1626 - reconstruction_loss: 142.6457 - kl_loss: 6.4149
# Epoch 3/30
# 547/547 [==============================] - 6s 11ms/step - loss: 149.1934 - reconstruction_loss: 142.6309 - kl_loss: 6.4122
# Epoch 4/30
# 547/547 [==============================] - 5s 10ms/step - loss: 148.6672 - reconstruction_loss: 142.4120 - kl_loss: 6.4015
# Epoch 5/30
# 547/547 [==============================] - 6s 10ms/step - loss: 148.6854 - reconstruction_loss: 142.3328 - kl_loss: 6.3978
# Epoch 6/30
# 547/547 [==============================] - 5s 9ms/step - loss: 148.2981 - reconstruction_loss: 142.1546 - kl_loss: 6.4149
# Epoch 7/30
# 547/547 [==============================] - 5s 9ms/step - loss: 148.5501 - reconstruction_loss: 142.0052 - kl_loss: 6.4319
# Epoch 8/30
# 547/547 [==============================] - 6s 10ms/step - loss: 148.6028 - reconstruction_loss: 142.0547 - kl_loss: 6.4199
# Epoch 9/30
# 547/547 [==============================] - 5s 9ms/step - loss: 148.1635 - reconstruction_loss: 141.8511 - kl_loss: 6.4257
# Epoch 10/30
# 547/547 [==============================] - 6s 10ms/step - loss: 148.0786 - reconstruction_loss: 141.7996 - kl_loss: 6.4454
# Epoch 11/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.6630 - reconstruction_loss: 141.6377 - kl_loss: 6.4377
# Epoch 12/30
# 547/547 [==============================] - 5s 10ms/step - loss: 148.2097 - reconstruction_loss: 141.6597 - kl_loss: 6.4377
# Epoch 13/30
# 547/547 [==============================] - 5s 10ms/step - loss: 147.7916 - reconstruction_loss: 141.5349 - kl_loss: 6.4385
# Epoch 14/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.5944 - reconstruction_loss: 141.4693 - kl_loss: 6.4631
# Epoch 15/30
# 547/547 [==============================] - 5s 10ms/step - loss: 147.6083 - reconstruction_loss: 141.4174 - kl_loss: 6.4445
# Epoch 16/30
# 547/547 [==============================] - 5s 10ms/step - loss: 147.4615 - reconstruction_loss: 141.3138 - kl_loss: 6.4539
# Epoch 17/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.5415 - reconstruction_loss: 141.2393 - kl_loss: 6.4576
# Epoch 18/30
# 547/547 [==============================] - 5s 10ms/step - loss: 147.2467 - reconstruction_loss: 141.0979 - kl_loss: 6.4665
# Epoch 19/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.3984 - reconstruction_loss: 141.1263 - kl_loss: 6.4699
# Epoch 20/30
# 547/547 [==============================] - 6s 11ms/step - loss: 147.4953 - reconstruction_loss: 141.0874 - kl_loss: 6.4662
# Epoch 21/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.7300 - reconstruction_loss: 140.9920 - kl_loss: 6.4872
# Epoch 22/30
# 547/547 [==============================] - 6s 10ms/step - loss: 147.2263 - reconstruction_loss: 140.9052 - kl_loss: 6.4881
# Epoch 23/30
# 547/547 [==============================] - 5s 9ms/step - loss: 146.9170 - reconstruction_loss: 140.7815 - kl_loss: 6.4911
# Epoch 24/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.0224 - reconstruction_loss: 140.7349 - kl_loss: 6.4840
# Epoch 25/30
# 547/547 [==============================] - 5s 10ms/step - loss: 146.9923 - reconstruction_loss: 140.6742 - kl_loss: 6.4955
# Epoch 26/30
# 547/547 [==============================] - 5s 9ms/step - loss: 146.9953 - reconstruction_loss: 140.6064 - kl_loss: 6.4925
# Epoch 27/30
# 547/547 [==============================] - 6s 10ms/step - loss: 147.0484 - reconstruction_loss: 140.6306 - kl_loss: 6.4904
# Epoch 28/30
# 547/547 [==============================] - 5s 9ms/step - loss: 147.2446 - reconstruction_loss: 140.5005 - kl_loss: 6.5130
# Epoch 29/30
# 547/547 [==============================] - 5s 9ms/step - loss: 146.8322 - reconstruction_loss: 140.5056 - kl_loss: 6.5034
# Epoch 30/30
# 547/547 [==============================] - 5s 10ms/step - loss: 146.8357 - reconstruction_loss: 140.3920 - kl_loss: 6.4957

# %% [markdown]
# ## Display a grid of sampled digits

# %%
import matplotlib.pyplot as plt

# n = value for x and y column
def plot_latent_space(vae, n=5, figsize=5):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# ## Display how the latent space clusters different digit classes

# %%
def plot_label_clusters(vae, data, labels):
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = vae.encoder.predict(data)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.show()


(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(vae, x_train, y_train)
# Out:
# 1875/1875 [==============================] - 3s 2ms/step

# %%
# graph training.csv
df = pd.read_csv('training.csv')
plot1 = (ggplot(df, aes(x='epoch', y='loss'))
        + geom_line()
        + labs(x='Epoch', y='Loss Value', title='Loss per Training Epoch'))
       # + theme_minimal())

plot2 = (ggplot(df, aes(x='epoch', y='reconstruction_loss'))
        + geom_line()
        + labs(x='Epoch', y='Reconstruction Loss', title='Reconstruction Loss per Training Epoch'))
        #+ theme_minimal())

plot3 = (ggplot(df, aes(x='epoch', y='kl_loss'))
        + geom_line()
        + labs(x='Epoch', y='KL Loss', title='KL Loss per Training Epoch'))
        #+ theme_minimal())


print(plot1)
print(plot2)
print(plot3)
